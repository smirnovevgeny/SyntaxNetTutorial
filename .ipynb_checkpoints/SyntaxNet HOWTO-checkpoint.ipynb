# %% [markdown]
# # Как использовать SyntaxNet
#
# Автор - **Евгений Смирнов**(jeka.mts@gmail.com)
#
# [SyntaxNet](https://github.com/tensorflow/models/tree/master/syntaxnet) - инструмент для построения синтаксических деревьев.
#
# В данном туториале расматривается:
#
# * Подготовка данных для SyntaxNet
# * Запуск SyntaxNet
# * Обработка его выхода
# * Выделение синтаксических веток из дерева
# * Отбор синтаксических коллокаций
# * Построение батчей из синтаксических веток
# * WSTM

# %%
import codecs
import pandas as pd
import numpy as np
from tools import *
import regex as re
import shutil
import time
import operator
from math import log
import csv

# %% [markdown]
# ## Подготовка данных для SyntaxNet

# %% [markdown]
# SYNTAXNET_MODELS_PATH --- путь к директории с моделями
#
# SYNTAXNET_MODELS_PATH/Russian-SynTagRus должна содержать модель для русского языка

# %%
# Folders
FOLDER = "data/"
FILES_FOLDER = FOLDER + "news/"
FOLDER_COLLOCATION = FOLDER + "collocations/"

# SyntaxNet 
SYNTAXNET_INPUT = FOLDER + "to_syntaxnet.txt"
SYNTAXNET_OUTPUT = FOLDER + "from_syntaxnet.txt"
SYNTAXNET_OUTPUT_PKL = FOLDER + "from_syntaxnet.pkl"
SYNTAXNET_MODELS_PATH = "~/Python_libs/models/syntaxnet/syntaxnet/models"

# ouput data
META_DATA = FOLDER + "meta_data.pkl"
DOCUMENT_SENTENCES = FOLDER + "document_sentences.pkl"
STOP_WORDS = FOLDER + "stop_words.txt"
BRANCHES = FOLDER + "branches.pkl"
COLLOCATIONS = FOLDER + "collocations.txt"

#dataFrames' columns
COLUMN_DOCUMENT_NAME = "document_name"
COLUMN_TITLE = "title"
COLUMN_URL = "url"
COLUMN_TIME = "time"
COLUMN_CATEGORY = "category"
COLUMN_SUBCATEGORY = "subcategory"
COLUMN_SENTENCE = "sentence"
COLUMN_LEMMATIED = "lemmatized"
COLUMN_BRANCH = "branch"
COLUMN_WITH_COLLOCATIONS = "with_collocations"

# %% [markdown]
# Подготовим список предложение, а также сохраним метаданные.
#
# **Грабли**:
# * Важно удалить все символы не относящиеся к русскому и англискому языкам, иначе могут возникнуть проблемы при лемматизации на следующем шаге.

# %%
documents_name = []
titles = []
urls = []
times = []
categories = []
subcategories = []

sentences = []
documents_id = []

file_list = os.listdir(FILES_FOLDER)
files_n = len(file_list)

for document_id, file_name in enumerate(os.listdir(FILES_FOLDER)):
    
    with codecs.open(FILES_FOLDER + file_name, encoding="utf-8") as input_file:
        input_lines = input_file.read().split("\n")
        
    documents_name.append(file_name)
    titles.append(input_lines[1])
    urls.append(input_lines[3])
    times.append(input_lines[5])
    categories.append(input_lines[7])
    subcategories.append(input_lines[9])
    
    for line in input_lines[11:]:
        for sentence in line.split("."):
            sentence_nopunctuation =  re.sub(ur'[^A-Za-zА-Яа-я ]', u'', sentence).lower().rstrip().strip()
            if sentence_nopunctuation:
                sentences.append(sentence_nopunctuation)
                documents_id.append(document_id)

meta_data = pd.DataFrame()
meta_data[COLUMN_DOCUMENT_NAME] = documents_name
meta_data[COLUMN_TITLE] = titles
meta_data[COLUMN_URL] = urls
meta_data[COLUMN_TIME] = times
meta_data[COLUMN_CATEGORY] = categories
meta_data[COLUMN_SUBCATEGORY] = subcategories
meta_data.to_pickle(META_DATA)

document_sentences = pd.DataFrame()
document_sentences[COLUMN_SENTENCE] = sentences
document_sentences.to_pickle(DOCUMENT_SENTENCES)

# %% [markdown]
# Запишем все предложения в один файл: на одной строчке одно предложение.

# %%
with codecs.open(SYNTAXNET_INPUT, "w", encoding="utf-8") as output:
    print >> output, "\n".join(sentences)

# %% [markdown]
# Запустим SyntaxNet

# %%
start_time = time.time()
if os.system("./run_syntaxnet.sh {} {} {}".format(SYNTAXNET_INPUT, SYNTAXNET_OUTPUT, SYNTAXNET_MODELS_PATH)) != 0:
    print ERROR_MESSAGE
print "It took {:.2f} seconds".format(time.time() - start_time)

# %% [markdown]
# Посмотрим на выходной файл от SyntaxNet

# %%
from_syntaxnet = pd.read_csv(SYNTAXNET_OUTPUT, encoding="utf-8", header=None, sep="\t", engine="c",
                             quoting=csv.QUOTE_NONE)
from_syntaxnet.head()

# %% [markdown]
# Обработаем выход SyntaxNet:
# * Селекция столбцов
# * Именование столбцов
# * Добавим колонку с лематизированным словами
# * Сделаем индексацию с нуля
#
# Сохраним результат в формате pickle
#
# **Грабли**:
# * не забываем про кодировку
# * иногда pandas может сломаться на следующей конструкции : **'"'** --- используем quoting=csv.QUOTE_NONE
#
# **Хотелки**:
# * Распараллелить работу mystem

# %%
from process_assessors_topics import syntaxnet_post_process
from_syntaxnet = syntaxnet_post_process(SYNTAXNET_OUTPUT)
from_syntaxnet.to_pickle(SYNTAXNET_OUTPUT_PKL)
from_syntaxnet.head()

# %% [markdown]
# ### Отбросим стоп слова
#
# **Грабли**:
# * не забудьте откинуть низкочастотные слова, если вам кто-то прислал свои стоп-слова перепроверьте их. Помните, большой словарь = долго длительное ожидание. Вряд ли низкочастотные слова сыграют ключевую роль в вашей модели.
#
# **Хотелки**
# * Для более честного отбора стоп-слов было бы здорово научиться сливать(стеминг не подходит) однокоренные слова в один токен

# %%
lemmas = dict()
for word in from_syntaxnet[COLUMN_LEMMATIED]:
    if word in lemmas:
        lemmas[word] += 1
    else:
        lemmas[word] = 1

# %%
lemmas_new = {token:frequency for token, frequency in lemmas.iteritems() if frequency <100}
values = np.array(lemmas_new.values())
plt.hist(values, bins=100)
plt.show()

# %%
stop_words = getSetFromFile(STOP_WORDS)
vocab = set([token for token, frequency in lemmas.iteritems() if frequency > 50])
vocab = vocab.difference(stop_words)
print len(vocab)
# Out:
# 14322

# %% [markdown]
# ## Выделение синтаксических веток из дерева

# %% [markdown]
# Синтаксическая ветка --- последовательность слов от корня дерева до любого из его листьев.
#
# Загрузим стоп-слова или словарь --- выбираем меньшее по мощности множетсов. Зададим части речи для фильтрации.
#
# **Грабли**:
# * стоп-слова лучше удалять на этом этапе чтобы не плодить одинаковые ветки
#
# **Хотелки**:
# * распараллелить

# %%
from Branches import *
branches = Branches(vocab=vocab, bad_tags={u'ADP', U'CONJ', U'AUX', U'PRON', U'NUM', U'SCONJ'})

# %% [markdown]
# Получим синтаксические ветки из результата синтаксического анализа.
#
# addTags --- Для каждой пары частей речи составим словарь частот соответствующих им словосочетаний.

# %%
branches.addDataFrame(from_syntaxnet, addTags=True)
# Out:
# word 18680000 from 18680047

# %% [markdown]
# Сохраним синтаксические ветки на диск

# %%
branchesDataFrame = branches.outputData.getDataFrame()
branchesDataFrame.to_pickle(BRANCHES)
print "\nЧисло веток - {}".format(len(branchesDataFrame))
branchesDataFrame.head()
# Out:
# Число веток - 4815055
#    sentence_id  branch_id                          branch word_ids_local  \
# 0            0          0               заканчиваться бой         [5, 0]
# 1            0          1       заканчиваться отступление         [5, 6]
# 2            1          0     начинать приближаться север      [6, 1, 3]
# 3            1          1  начинать борьба артиллерийский      [6, 8, 7]
# 4            1          2        начинать борьба крепость     [6, 8, 10]
#
#   word_ids_global
# 0          [5, 0]
# 1          [5, 6]
# 2     [14, 9, 11]
# 3    [14, 16, 15]
# 4    [14, 16, 18]

# %% [markdown]
# ## Отбор синтаксических коллокаций

# %%
n_pairs = sum([sum(pairs.values()) for key, pairs in branches.dictionary_pairs.iteritems()])
n_words = sum(branches.dictionary_frequency.values())
norm_coef = float((n_words) ** 2) / n_pairs

def filter_pairs(pairs, threshold_frequency, threshold_pmi):
    pairs_sorted = sorted(pairs.items(), key=operator.itemgetter(1), reverse=True)
    new_elements = []
    for element in pairs_sorted:
        pair = element[0]
        frequency = element[1]
        if frequency > threshold_frequency:
            pmi = log(norm_coef * frequency / branches.dictionary_frequency[pair[0]]
                      / branches.dictionary_frequency[pair[1]])
            if pmi > threshold_pmi:
                new_elements.append(((" ".join(pair)), frequency, pmi))
    return new_elements

# %% [markdown]
# Для кажой из пар частей речи создадим файл с наиболее частыми словосочетаниями
#
# В этом месте наступает творческо-асессоркий момент. Чем лучше эвристики для отбора придумаете, тем лучше будут коллокации. Если творчество подводит, то всегда можно компенцировать этот недостаток асессорским трудом. Советую задать менее жесткие фильтры для отборы и внимательно отобрать принципом длительного вдумывания.

# %%
checkDirectory(FOLDER_COLLOCATION)
        
for key, pairs in branches.dictionary_pairs.iteritems():
    elements = filter_pairs(pairs, 50, 6)
    if elements:
        
        output = []
        for element in elements:
            output.append(u"{}: {} {:2}".format(element[0], element[1], element[2]))
                
        with codecs.open("{}{}.txt".format(FOLDER_COLLOCATION, key), "w", encoding="utf-8") as ouputFile:
            print >> ouputFile, "\n".join(output)

# %% [markdown]
# Проведем асессорскую фильтрацию.
#
# Далее, сформируем список коллокаций.

# %%
collocations = []
for file_name in os.listdir(FOLDER_COLLOCATION):
    if not file_name.startswith("."):
        with codecs.open(FOLDER_COLLOCATION + file_name, encoding="utf-8") as input_file:
            collocations += [line.split(":")[0] for line in input_file.read().splitlines()]
with codecs.open(COLLOCATIONS, "w", encoding="utf-8") as output_file:
    print >> output_file, "\n".join(collocations)
print "Выделено {} коллокаций".format(len(collocations))
# Out:
# Выделено 4085 коллокаций

# %%
from preprocess_line import CollocationSyntax, add_collocation

# %%
lines = list(branchesDataFrame[COLUMN_BRANCH])

collocations = []

for collocation in getListFromFile(COLLOCATIONS):
    collocations.append(CollocationSyntax(collocation))
    
collocations_n = len(collocations)
    
all_branches = "\n".join(lines)
    
for i, collocation in enumerate(collocations):
    if i % 10 == 0:
        dynamicPrint("added collocation {} from {}".format(i, collocations_n))
    all_branches = add_collocation(all_branches, collocation)
# Out:
# added collocation 4080 from 4085

# %%
new_lines = all_branches.split("\n")
for i, line in enumerate(new_lines):
    if not line:
        del new_lines[i]

# %% [markdown]
# Сохраним ветки на диск

# %%
branchesDataFrame[COLUMN_WITH_COLLOCATIONS] = new_lines
branchesDataFrame.to_pickle(BRANCHES)

# %% [markdown]
# # WSTM

# %% [markdown]
# ### Создадим Vowpal Wabbit из синтаксических веток

# %%
from create_ww_and_pmi_count import main as prepare_batches

# %%
prepare_batches(branchesDataFrame[COLUMN_WITH_COLLOCATIONS], FOLDER, 7)
# Out:
# save wv to SyntaxNet/ww_vw.txt
#
# pair 9203000 from 9203565
# save vocab to SyntaxNet/vocab.txt
#
# 17090 from 17091
# save pmi to SyntaxNet/pmi.txt
#
#
# Time elapsed: 358.162 sec.

# %%
import artm

# %%
PMI_PATH = FOLDER + "pmi.txt"
VOCAB_PATH = FOLDER + "vocab.txt"
PATH_TO_WW_VW = FOLDER + 'ww_vw.txt'
FOLDER_BATCHES_WW = FOLDER + "batches/"

# %%
def prepare(redo=False):
    global bv_ww
    
    if redo and os.path.exists(FOLDER_BATCHES_WW):
        shutil.rmtree(FOLDER_BATCHES_WW)
        
    if not os.path.exists(FOLDER_BATCHES_WW):
        bv_ww = artm.BatchVectorizer(data_path=PATH_TO_WW_VW, data_format='vowpal_wabbit',
                             target_folder=FOLDER_BATCHES_WW)
        d = artm.Dictionary()
        d.gather(data_path=FOLDER_BATCHES_WW, cooc_file_path=PMI_PATH, vocab_file_path=VOCAB_PATH)
        d.save(dictionary_path=FOLDER_BATCHES_WW + '/cooc_dict.dict')
    else:
        bv_ww = artm.BatchVectorizer(data_path=FOLDER_BATCHES_WW, data_format='batches')

# %% [markdown]
# Загрузим/создадим батчи, словарь

# %%
prepare(True)

# %%
def createTopics(domain_n=90, background_n=10):
    global DOMAIN_N, BACKGROUND_N, string_id
    DOMAIN_N = domain_n
    BACKGROUND_N =  background_n
    string_id = "d{}_b{}".format(domain_n, background_n)
    global topics_background, topics_domain
    topics_domain = ['topic_d{}'.format(i) for i in xrange(domain_n)]
    topics_background = ['topic_b{}'.format(i) for i in xrange(background_n)]

# %%
def addScores():
    model.scores.add(artm.PerplexityScore(name='PerplexityScore',
                                                  dictionary=cooc_dict))
    model.scores.add(artm.SparsityPhiScore(name='SparsityPhiScore', topic_names=topics_domain))
    model.scores.add(artm.SparsityThetaScore(name='SparsityThetaScore', topic_names=topics_domain))
    model.scores.add(artm.TopicKernelScore(name='TopicKernelScore',
                                           topic_names=topics_domain, probability_mass_threshold=0.3))
    model.scores.add(artm.TopTokensScore(name='TopTokensScore',
                                         num_tokens=50, dictionary=cooc_dict))

# %%
def printTopics(topics, num=70, print_file=False):
    Phi = model.get_phi()
    zeros = 0
    string_to_print = ""
    for i, topic in enumerate(topics_domain + topics_background):
        if topic in topics:
            topicSeries = Phi[topic].sort_values(ascending=False)[:num]
            indexes = topicSeries > 0
            result = topicSeries[indexes].index
            string_to_print += topic + ":[{}/{}] ".format(len(result), sum(Phi[topic] > 0)) + " ".join(result) + "\n"
            zeros += len(result) == 0
    print string_to_print
    if print_file:
        with codecs.open(FOLDER + 'topics_d{}_b{}.txt'.format(DOMAIN_N, BACKGROUND_N), 'w', 'utf8') as outputFile:
            print >> outputFile, string_to_print

# %% [markdown]
# Зададим число предметных и фоновых тем

# %%
createTopics(domain_n=400, background_n=10)

# %%
cooc_dict = artm.Dictionary(dictionary_path=FOLDER_BATCHES_WW + '/cooc_dict.dict')
model = artm.ARTM(topic_names=topics_domain + topics_background, dictionary=bv_ww.dictionary,
                  num_document_passes=1, cache_theta=True, theta_columns_naming="title", reuse_theta=True)
addScores()
model.initialize(dictionary=cooc_dict)

# %% [markdown]
# Поитерируем пока модель не сойдется

# %%
model.fit_offline(batch_vectorizer=bv_ww, num_collection_passes=40)

# %% [markdown]
# Сгладим фоновые темы и декоррелируем предметные

# %%
model.regularizers.add(artm.SmoothSparsePhiRegularizer(name='SmoothPhi', tau=0.02, topic_names=topics_background))
model.regularizers.add(artm.SmoothSparseThetaRegularizer(name='SmoothTheta', tau=0.02, topic_names=topics_background))
model.regularizers.add(artm.DecorrelatorPhiRegularizer(name='DecorrelatorPhi',
                                                       tau=500000, topic_names=topics_domain))

model.fit_offline(batch_vectorizer=bv_ww, num_collection_passes=100)

# %%
df_scores = pd.DataFrame(data = {'Sparsity Phi' : [round(model.score_tracker['SparsityPhiScore'].last_value, 3)],
                    'Sparsity Theta' : [round(model.score_tracker['SparsityThetaScore'].last_value, 3)],
                    'Kernel contrast' : [round(model.score_tracker['TopicKernelScore'].last_average_contrast, 3)],
                    'Kernel purity' : [round(model.score_tracker['TopicKernelScore'].last_average_purity, 3)],
                    'Coherence' : [round(model.score_tracker['TopTokensScore'].average_coherence[-1], 3)],
                    'Perplexity' : [round(model.score_tracker['PerplexityScore'].last_value, 3)]},
                    index = ['1'])
df_scores
# Out:
#    Coherence  Kernel contrast  Kernel purity  Perplexity  Sparsity Phi  \
# 1      0.959            0.584          0.639    1376.924          0.86
#
#    Sparsity Theta
# 1           0.784

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
# convergence
x = range(len(model.score_tracker['PerplexityScore'].value[1:]))
fig, ax1 = plt.subplots(figsize=(8, 6))
ax1.plot(x, model.score_tracker['PerplexityScore'].value[1:], 'g-', linewidth=2, label="Perplexity")
ax1.set_xlabel('Iterations count')
ax1.set_ylabel('Perplexity', color='g')
ax2 = ax1.twinx()
ax2.plot(x, model.score_tracker['SparsityPhiScore'].value[1:], 'r*', linewidth=2, label="Phi sparsity")
ax2.plot(x, model.score_tracker['SparsityThetaScore'].value[1:], 'r--', linewidth=2, label="Theta sparsity")
ax2.set_ylabel('Ratio', color='r')
ax2.legend(bbox_to_anchor=(1.10, 1), loc=2, borderaxespad=0.)
plt.grid(True)
fig.savefig(FOLDER + 'convergence{}_{}.eps'.format(DOMAIN_N, BACKGROUND_N), bbox_inches='tight')
plt.show()
    
# interpretability
x = range(model.num_phi_updates)[1:]
fig, ax1 = plt.subplots(figsize=(8, 6))
ax1.plot(x, model.score_tracker['TopTokensScore'].average_coherence[1:], 'g-', linewidth=2, label="size")
ax1.set_xlabel('Iterations count')
ax1.set_ylabel('Coherence top50', color='g')
ax2 = ax1.twinx()
ax2.plot(x, model.score_tracker['TopicKernelScore'].average_contrast[1:], 'r*', linewidth=2, label="contrast")
ax2.plot(x, model.score_tracker['TopicKernelScore'].average_purity[1:], 'r--', linewidth=2, label="purity")
ax2.set_ylabel('Ratio', color='r')
ax2.legend(bbox_to_anchor=(1.10, 1), loc=2, borderaxespad=0.)
plt.grid(True)
fig.savefig(FOLDER + 'interpretability{}_{}.eps'.format(DOMAIN_N, BACKGROUND_N), bbox_inches='tight')
plt.show()
plt.clf()

# %%
printTopics(topics_domain + topics_background, print_file=True)
# Out:
# topic_d0:[70/1857] известный исполнять сниматься сыграть играть прославляться исполнение доставаться женский придумывать мужской представать важный выдвигаться исполнительница выбор запоминаться доктор прозвище отводить примеривать ложиться традиционный комедия неизвестно попробовать отказ тор рояль хит совмещать распределять перепутывать укреплять заказчик любимый отводиться подталкивать ньюйорка занятый щит воссоединяться намекать познакомиться похвалить питер феникс наставник знаменитый преподавать станцевать чей спорить сосредотачиваться помнить приписывать имитация стоун поспорить фильмография гласить гендерный вызов исполняться пробовать мистер биографический исполнение_отстранять дерзкий росомаха
# topic_d1:[70/2434] размер сумма денежный особо хищение мошенничество вознаграждение взятка_получение выручать выделение перевод взыскание возврат отмывание выражение наличный собранный расходование франк вовлекать вкладывать легализация эпизод взятка незаконно косметический вымогательство выделяться растрата сокрытие остаток вымогать имущество_хищение выводиться присвоение физлиц обвиняться покровительство совокупность материальный транспортный купюра уклонение обналичивать значительный списание отток выплачиваться мошенничество_совершенный присвоение_растрата уплата вкладчик махинация санкционировать kickstarter выигрыш предъявляться размещение выписывать привлечение порог исчисляться обвинение_растрата транспортировка завышать поощрение возмещение_выплата разыскиваться распоряжение положенный
# topic_d2:[70/4060] критика реакция резонанс возмущение недовольство резкий осуждение жесткий допрос общественность неоднозначный дискуссия шутка негодование бурный преследование сомнение нападки шквал вызывать_реакция недоумение адрес_критика возражение беспокойство волна тревога спор опасение негативный разногласие правозащитник обрушиваться обеспокоенность сожаление озабоченность нарекание давать_обещание вызывать_резонанс эмоция гнев интернетпользователь ажиотаж насмешка волнение критик разъяснение воздействие острый пытка удивление всплеск паника цензура республиканец притеснение аплодисменты оппонент реплика наряд дальнобойщик восточноевропейский беспрецедентный общественник противоречивый лоза государствчлен недовольный объяснение репрессия враждовать
# topic_d3:[70/5084] форум мероприятие конференция церемония визит саммит прессконференция открытие фестиваль выступление выставка премьера презентация концерт торжественный ежегодный делегация париж показ запланировать вашингтон кинофестиваль парад пмэф воскресение поле преддверие организатор гость открываться сессия конгресс вечер поездка площадка конкурс съезд приглашение шоу приурочивать совместный праздничный пекин сочи митинг соревнование брюссель празднование кулуары бой ньюйорк награждение свадьба лондон учение олимпиада собрание отменять ночь владивосток лекция марш берлин слушание брифинг торжество продемонстрировать продлиться сорвать закрытый
# topic_d4:[70/2100] питание изделие отходы лекарство вредный переработка кладь медикамент багаж сырье лекарственный бытовой пищевой ручной химический продовольствие провоз кондитерский цех добавка радиоактивный гигиена мешок мусор питание_продукт сжигание утилизация удобрение изготавливаться импортный табачный еда твердый посуда вывоз одеяло сбор волокно жизненно химия ингредиент снаряжение субстанция спальный гмо остаток органический вещество_выброс шоколад корм порошок кислота древесина загрязнять компонент мясо_рыба вещь упаковка перерабатывать натуральный стройматериал утилизировать нехватка мыло разрешаться посылка горение промышленный выбрасывать бронежилет
# topic_d5:[70/4110] администрация кремль минобороны госдепартамент пентагон госдеп резиденция псаки помиловать кирби основание_распоряжение докладывать госадминистрация генералмайор пост_претендент временный баллотироваться_пост окружение ога избранный брифинг свержение харф послание мэрия инаугурация свергать посольство бегство полпред полномочный ржд йемен мадуро тогдашний венесуэла портрет земан сбербанк роснефть лукойл пресса абд саркозить хасан адресовать конгресс total лояльный пак неназванный оскорбление баллотироваться бежать общаться цска автоваз сечина нефтяной приказывать еврейский дипмиссия служащий полковник футболка федерация_хоккей башкирия диппредставительство третьяк академия
# topic_d6:[70/93] изъявлять риторика задействовать_инструмент искренний сочувствие извинять наказание_понести выражать_соболезнование давать_отпор ктонибудь налагать_штраф трамвай извинение_приносить отклонять_ходатайство ктолибо выдвижение_кандидат пхенчхан мобилизационный цитрусовый благодарность_выражать поразному фальшивка prada продукция_рыбный декада свеча пособник_террорист classic контрольный_пакет change пан_секретарь конфедерация_футбол мера_ограничительный кровотечение полномочие_слагать издавать_книга объемный балерина югра сармат внутрироссийский charlie_еженедельник промоутерский недоразумение выборгский young застреливаться исправлять_ошибка инициал функциональный подымать_тревога вина_признавать отставка_уходить armani обидчик сенсорный zeppelin диагноз_поставлять непредсказуемый periscope властный долевой глазго чудовищный книжка заливать бейсбольный замгендиректор тупой paris
# topic_d7:[70/1406] рейтинг прогноз понижать замыкать ухудшать forbes негативный топ moodys рейтинговый долгосрочный baa суверенный богатый снижать standard bbb строчка кредитный fitch poors ступень рейтинг_строчка составление составляться дефолт шкала тройка опускаться потолок учитываться bloomberg bb букмекер wta высокооплачиваемый обновлять женский теннисный понижение ba десятка инвестиционный глобальный ежегодный ниже дорогой пересмотр влиятельный составитель топлистый спекулятивный вслед греция пессимистичный эмитент понижение_рейтинг перемещаться краткосрочный предрекать tripadvisor теннисистовпрофессионал стабильный теннисистка сбываться смещать itunes мусорный классификация индекс
# topic_d8:[70/816] включение актерский подвижной дезертир офицерский авиагруппа наличие_сбор подвижный средиземноморский обновляться авиабригада_назначение джейши дублировать строение личной патриотический дестабилизация_обстановка латакия зачислять численный руководящий парадный дебютировать предусмотренный_статья пополнять дубль синегранатовый обращаться_просьба развернутый белоголубой жюри упразднять рсфср корабельный взамен найм исчисление бортинженер товарный дебют расширенный поверхность_строение синебелоголубой стэнли cocacola боекомплект парижанин отставка_уходить нпк стационарный возобновление_договариваться претерпевать дальнобойный юта сопоставлять зарекомендовать расширяться сливочный укроборонпром уссурийск шерить минерал лиман итальянка топменеджмент микрофлора создаваемый зацепляться привидение аргумент
# topic_d9:[70/1002] автомобиль машина авто мотоцикл автомашина иномарка скрывать легковушка велосипед катер фургон подушка грузовик автолюбитель трактор газель автомобильный задний карета_помощь легковой кресло ремень прошлое эвакуатор лишаться коробка шасси болид коляска передний карета свободно напечатать неправильно камаз числиться стартовый легкое сидение электромобиль немецкий джип изготовитель кенгуру микроавтобус вышка инаугурация знакомиться орлан единица_техника кузов должностной_полномочие вплоть mc пригодный внедорожник возобновление_договариваться параллельно распадаться автомобиль_угнать вывести хвостовой земляк отзываться взимать робот автобус_пассажирский sms мебель прозрачность
# topic_d10:[70/1059] имущество преступный инкриминироваться легализация недвижимость доход_легализация башнефть урал оборонсервис приватизация отмывание чужой занижать национализировать инкриминировать башкирский растрата доход_отмывание недвижимый распродавать чиновница тэк легализация_мошенничество предприятие_тэк конфискация отчуждение фигурантка имущество_хищение присвоение имущественный сговор присвоение_растрата конфисковать нецелевой порча легализация_отмывание гайзер злоупотребление изъятие башкирия раздел завладение вверять подконтрольный путем повреждение эпизод земельный мошеннический госсобственность подведомственный возбужденный кировлес вменяться арестованный заведомо замораживание взыскание госпредприятие екатеринбургский артек декларация последующий заключение_конфискация юкос наложение умысел госимущество приватизировать реставрационный
# topic_d11:[70/1189] пресссекретарь песок рст прессатташе еврокомиссар союз_туриндустрия лобушкин туриндустрия ффккр итартасс кремль авдеевка питер приверженный уоррен стивенс нагорнокарабахский прорабатываться разъяснять цеголко опытный ампелонский навка затрудняться заверение резюмировать докладывать контрадмирал процитировать конькобежец_союз новгородский полпред охарактеризовать еврокомиссар_энергетика предрекать петров задеть преподносить басманный спартак усомниться неизвестно поинтересоваться комендант обширный обезопасить намечаться фтр peter комиссар дельфин воздерживаться сопровождение репортаж сожалеть пляж уместный мешок богатство вопрос_задаваться выяснение эттингер видеозапись_обнародоваться варшава джей пост_претендент бетон янтарь рей правление_председатель
# topic_d12:[70/1320] главный ключевой эпизодический ассистент старший решающий второстепенный толерантность симоньян снабжение главное помощница основный заслуживать цензор графический консультировать линейный ясный профессор любовница основательница дуэт передвигаться гендерный персональный радиостанция_эхо выписка воробей карикатурист коллаж знарка логистический шефредактор ланнистер декорация колин дуэль талисман похоронить встраивать дикий офисный заслуженный обрабатывать рисовать мужской хопкинс кон предписание продавщица существенный гордость нэшвилл франк цру сложно отсрочка неопределенность арсенал трамвай муфтий легендарный попробовать мороз чрезвычайно отражаться дель восхищаться безусловный
# topic_d13:[70/3524] версия разрабатывать разработка производство база тип оборудование самолет построить заменять вестись вариант производить использование оснащать разрабатываться основа образец поколение модернизация включая технология способный выпуск стоять приобретать предназначать платформа производиться тяжелый создаваться элемент устройство состоять предполагаться семейство заказ заказывать продемонстрировать покупка замена перспективный современный различный отличаться закупать установка выпускать модификация качество изготавливать основной полет материал количество класс располагать выпускаться обладать должно относиться задача модель закупка эксплуатация устаревать сборка назначение прототип приобретение
# topic_d14:[70/1286] поставка поставлять закупка экспорт закупать импорт поставляться поставщик покупать ограничиваться отгрузка ставить доставка нехватка покупка касаться возможность_рассматривать экспортировать дефицит снабжать снабжение экспортер госпрограмма отгружать закупаться поступление летальный приобретение потребность отправка торговать вывоз прием остальной перепродавать перебой перемещение ввоз заказ_портфель сбыт импортер покупатель импортировать сброс вывозиться кнр вывод_приходить сдерживание транзит упоминать возобновление египет обеспечиваться передаваться сходиться наступательный месть непригодный скопление ти нераспространение переброска судиться дистрибьютор южноафриканский продажа запрещаться лишний газпром пробел
# topic_d15:[70/3311] погибать пострадать ребенок погибший ранить убивать пропадать пострадавший сотня включая обстрел жертва гибель мирный спасать числиться десяток россиянин военнослужащий повреждать семья поиск потерять выживать уничтожать столкновение тело сгорать раненый уносить приносить ранение родственник возрастать упасть возникать автобус эвакуировать полицейский минометный образовываться обрушиваться солдат корнелюк наступать вгтрк скончаться убитый завязываться эвакуация журналист_телекомпания судьба тяжело сведение сходить офицер останки шахта попадание последовать выплачивать палестинец причинять рухнуть донецк корреспондент ликвидировать минимум весть умирать
# topic_d16:[70/1953] северный южный океан побережье берег тихий балтийский средиземный архипелаг атлантический южнокитайский река залив карибский индийский затонуть курильский эгейский спорный японский греческий тихоокеанский югозападный ледовитый дно обитать черноморский арктический шпицберген атлантика кндр сахалин мыс искусственный яванский канарский камчатка глубина пролететь пролив риф гавайский охотский реюньон аляска карский тузла шельф норвежский озеро желтый учение итуруп чукотка обрушиваться зеленый подледный гуам добираться абхазия бали корейский открытый дрейфовать утопать пляж чукотский гренландия окинава азовский
# topic_d17:[70/3408] захватить теракт устраивать нападение атака париж ликвидировать мужчина серия боевик террорист жертва убивать нападывать стрельба штурм пригород charlie взрыв брат атаковать hebdo прозвучать кулибать захват взрывать ответственность ворваться уничтожать брюссель организатор расстреливать прогреметь куашь спецоперация освобождать офис разыскивать ночь предполагать ранить грозный перестрелка парижский посольство задержание исламист сатирический супермаркет французский подозреваемый проникать совершенный нападать рейд готовиться освобождение экстремист причастность вечер брать шериф преступник распространять хакерский журнал причастный смертник стоять поимка
# topic_d18:[70/3010] обвинять расследование совершать проверка факт связывать лицо подтверждать заниматься деятельность подозревать журналист цель обвиняться осуждать причастный причастность проверять подозреваться предъявлять подозрение применение ответственность версия связанный арестовывать материал скандал гражданин проводиться летний расследовать заподозривать обвинение подготовка подозреваемый указывать отстранять инициировать призыв организовывать полагать обвиняемый попытка житель исключать совершение виновный касаться расценивать участвовать вывод аэропорт признаваться следствие привлекать осуществлять чиновник заключать участник приговаривать организатор крупный схема допускать прокомментировать заключение предотвращать признак задержание
# topic_d19:[70/4446] мнение большинство население опрос опрашивать проголосовать россиянин респондент участник мирный гражданин отдавать минимум полагать подавлять избиратель половина треть оценка придерживаться уверенный предпочитать участвовать пользоваться проживать согласный активный многий относиться некоторый численность примерно голосовать доверять изучение верить страдать четверть приходить остальной аналитик зрение пользователь американец признаваться позиция опасение убеждать подсчитывать пропорционально распределяться турист состоять британец затрудняться москвич рекомендовать разделять посчитать выясняться недовольный сходиться старый популярный соглашаться взрослый опасаться русскоязычный испытывать душа
# topic_d20:[70/4229] отрасль промышленность бизнес сфера отечественный технология торговля производство инвестиция сегмент нефтяной промышленный оборонный хозяйство экспорт туристический доля зарубежный энергетический продвижение финансовый затрагивать инвестировать газовый информационный вкладывать индустрия энергетика развивать стимулировать интернет розничный малый внутренний ведение оборудование собственный регулирование инновационный глобальный расширять частный стратегический коммерческий технологический совместный космический автомобильный нефтегазовый специализироваться привлечение китайский высокотехнологичный объединять различный транспортный сельский развиваться импортозамещение экспортный заинтересовывать отдельный капитал банковский расширение ракетнокосмический корпоративный сельскохозяйственный транспорт строительный
# topic_d21:[70/5815] качество технология метод способ материал определять форма опыт способный механизм инструмент вариант процесс пример вид анализ структура модель элемент функция надеяться использование особенность подход правило язык тип продукт схема применять препарат необходимо практика стратегия различный сценарий алгоритм формат эксперимент применяться свойство набор поиск характеристика предмет эффект параметр множество современный способность ресурс искать методика устройство прием искусственный степень показатель достижение навык маршрут изображение эффективность понимать определение предстоять дизайн расчет стандарт выбор
# topic_d22:[70/751] крым полуостров севастополь ялта симферополь субъект евпатория меняйло воссоединение крым_присоединение керчь жемчужина национализировать ленинград вхождение значение север банкнота рк материковый координатор севастополь_симферополь порт заксобрание алушта процедура_соответствовать битва мотивировать предоставляться последующий чф массандра организатор годовщина_празднование арктика крымский формулировка заходить годовщина ялтинский приднестровье некий поддерживаться херсонес легитимный высылать разоблачение бухта персона кабардинобалкария таможенный добровольный вносить_законопроект грат_нона отдельно юг калининградский осознавать евразийский закарпатский таврический забывать перерегистрация растягиваться новороссийск годовщина_приурочивать тс учебник эксглава кантон
# topic_d23:[70/3624] матч чемпионат игра состояться тур сыграть счет сборная футбол первый обыгрывать встреча турнир финал серия раунд этап проигрывать передача групповой европа англия рамка состав бразилия конец национальный кубок проведение зенит цска подготовка финальный уступать первенство тур_этап пропускать играть открывать регулярный евро игрок плейофф удаваться испания московский поединок домашний спартак летний дисквалифицировать франция суметь отборочный динамо германия мировой окончание полуфинал наказывать россиянин локомотив поле хозяин выход посещать товарищеский квалификация вничью завершать
# topic_d24:[70/3937] район житель располагать аэропорт улица открывать станция площадь столица совершать остров московский находить путь движение километр располагаться округ объект закрывать парк упасть сторона регион поселок проживать проспект база жить планироваться недалеко большой донецк взрыв прибывать построить центральный направляться собираться порт направление удаваться отправляться перекрывать покидать открываться городской следовать неподалеку обстреливать шоссе эвакуировать стоять посещать завод север крупный площадка размещать контроль мск садиться полиция вокзал предел уточнять юг принадлежать кольцо поле
# topic_d25:[70/1571] отель ресторан гостиница кафе посетитель бар пляж кухня кинотеатр hotel блюдо пятизвездочный бутик казино супермаркет постоялец гостиничный меню универмаг шефповар спальня бассейн апартамент вилла еда персонал каюта отдыхать_турист завтрак паб гум фастфуда общепит radisson двухместный цум туалет кофейня люкс небоскреб сити развлекательный номер ванный вечеринка bulgari повар цирк столовая столик сидней обед курение пиццерия burger развлечение park grand king подраться попробовать санаторий поезд_следование le курить хостел кафе_ресторан de приготавливать фламинго
# topic_d26:[70/1521] федерация ассоциация союз фифа ассоциация_союз футбол вицепрезидент бизнес конфедерация чиновник оштрафовать конгресс объявлять_розыск интеграция консорциум исполком хоккей функционер исполнять_обязанность фхр оргкомитет отстранение коррупция легкоатлет эгида раввин присуждать заводить трибунал вступление штабквартира iihf конференция зал_слава мутко соревнование бассейн спорт бокс дипломатия регламент исполком_член генсек наказывать континент исполком_союз комиссар исполнение вицепрезидент_исполком общественность заявка любитель делегат мяч уход выдвижение устав предсказывать приостановка атташе индустрия подводить заручаться_поддержка соревнование_эгида имидж федерация_хоккей ресторатор откладывать расизм ффу
# topic_d27:[70/3596] прорвать прорваться спасаться залив провозить выяснивать поймать выбираться нелегальный перелезать проволока забор отбивать покончить заграждение проникать перебираться колючий помешать сбегать вырываться самоуправление проваливаться взбираться безуспешно предотвращать оцепление неудача прорыв вывозить трудовой пробираться выживать пресекать ввозить подкупать урна оспаривать спрятаться окружать навязывать преодолевать ограда неудачный давление_оказывать связываться ограждение убегать пронести кордон уговаривать успокаивать наплыв бетонный баку разбирать сооружать переписывать переправлять напугать увенчиваться граница_пересекать дестабилизировать проникновение подавлять предприниматься оттеснять вытеснять расстреливать контакт_налаживать
# topic_d28:[70/2628] запрет продукция товар продукт ввоз ограничивать импорт молочный эмбарго овощ_фрукт овощ_продукция молоко ограничение норвегия австралия_канада производство продовольственный говядина_свинина рыба препарат морепродукт_рыба мясной запрет_импорт экспорт продовольствие производитель охлаждать назначение производить оборудование сыр сельскохозяйственный ввоз_запрещать ввоз_запрет мясо ввозить фрукт ввоз_ограничение некоторый евросоюз исключать рынок перечень молоко_сыр мясо_птица запрещаться сырье птица свинина рф морепродукт двойной реализация импортный цветок алкогольный реэкспорт изделие пошлина поставщик подлежать рыбный соль категория растительный останавливать происхождение овощ сельхозпродукция покупать
# topic_d29:[70/1328] рфс уефа этика блаттер платини счетный швейцарский евразийский рфс_союз исполком таможенный кдк исполком_член цюрих военнопромышленный туриндустрия биатлонист регламент мокнуть симонянин капелло торговопромышленный кинематографист спор толстый участковый ibu рса биатлонист_союз штабквартира ффу вещательный функционер заседание_исполком тмам мутко монументальный оп контрольнодисциплинарный распад переизбирать апелляция арбитражный велосипедист сбр конькобежец новороссия инфантино молодежь страховщик правообладатель астрономический наказывать присуждать африканский дзержинский генсек жеребьевка судейство соревнование_эгида межведомственный погасить рсп мма союзмолоко межправительственный коэффициент pyd лорд отраслевой
# topic_d30:[70/915] дочь мать сестра кардашьян бабушка фотомодель лейтенант внучка телезвезда семейство суррогатный отчим изготовление_мастер louis_основывать выгонять реалитишоу аутизм сержант дедушка стенкамп женатый детство знакомая спешить светский звание_лейтенант сфотографироваться филлипс заря консул дочка уэст няня хасан мастер кайлить оканчивать_училище кание_уэст мосс отыскивать двоюродный зять прогуливаться последовать_пример схожий бельгиец ныне раскупать нижегородский корень local ына наполнять бракосочетание институт_оканчивать класс_ученик оплодотворение племянник куриный назваться аналитика обозрение смелость армянский плантация память_почтить сходство кинокартина механик предвзятый
# topic_d31:[70/2554] пассажир экипаж судно борт пилот командир затонуть капитан весть спасать кабина летчик катапультироваться моряк перевозить член_экипаж траулер штурман пехотинец паром экспедиция спасательный остальной астронавт успевать крушение бортинженер спасение морской теплоход пар восток_траулер космонавт любица спасаться рыбак матрос ошибка закрываться высаживать перевертываться подполковник танкер персонал де_имя иностранец запираться катер яхта мкс севоля формула подымать тонуть выживать десантник нефтяной подбивать маржери бортпроводник порт судьба терпеть поисковоспасательный рассчитать воздействие квят пассажирка южнокорейский total
# topic_d32:[70/1556] физический юридический должностной лицо_физический неустановленный fonseca_фирма офшорный доверенный юрлица физлиц служебный перемещать штрафовать указанный посторонний распознавание подставной распознавание_технология застраховывать целый выражение черта подозрительный замораживание инвалид пониматься наложение покушение_убийство ндфл росимущество величина замещать резидент ожог перечисляться избранный сговор умерший давление_оказывать ударять накладывать ответственность_привлечение перерегистрация косметический руководящий возбуждать_факт незаконно трактовать национальность распознавать кредитор_настаивать должность_занимать неосторожность_причинение беременность_прерывание популяризация конкретный период_президентство присуждаться планирование менеджмент контролироваться шутер осужденный функционал оговорка юрисдикция интернетпровайдер растительность имущество_хищение чей
# topic_d33:[70/671] рекламный предвыборный бок кубинский цветной варшавский агитационный сюжетный краудфандинговый оранжевый экспресс kickstarter выборный октябрьский откат дворник пропагандистский сервисный антиправительственный burberry bucket слоган активистка саркозить maxim versace антикоррупционный благотворительный challenge информирование gabbana фотографироваться обливаться magazine prada авторство жалеть als февральский берня бесконечный разгар январский pornhub повстанец маркетинговый хештег кенийский make chanel общероссийский энтузиаст матрос dolce спонсорский обжалование dior опрокидываться бросать_вызов рождаемость gucci подписной подхватывать атрибут абитуриент ама белорус трансферный мобилизационный устроитель
# topic_d34:[70/93] прекращать welle банк_смп собинбанк запрет_налагать приостановление оэз лицензия_отзыв негласный уязвимый ратифицировать_соглашение corp радиостанция_эхо вышеуказанный ой пластиковый изучаться необходимость_обосновывать райффайзенбанк нештатный дальспецстрой урегулировать jacobs волосок грибаускать раскупать приостанавливаться дагестанский заговаривать анклав оповещать маньяк перестройка ирландский последовать_пример воспрепятствовать всякий дельфин свертывать портовый кстати запугивание слабость уверенно запечатлевать испытывать_трудность одновременный интернетплощадка ажиотаж боязнь преподносить заверение перерегистрация нести_ответственность выгодно совершаться верховенство блокироваться политзаключенный starbucks прерываться виток недопустимо рсмд лицензия_отзывать доставляться простаивать дефакто поприветствовать целенаправленный
# topic_d35:[70/728] нигерия хары гвинея боко либерия мали сьерралеон сомали сенегал конго камерун нигер западноафриканский либерия_распространяться чадо распространяться_сьерралеон судан заражение_случай либерия_сьерралеон нигерийский контекст раб экваториальный вырывать флирт воз котдивуар северовосток тунис бесплатно буркинафасо марокко эфиопия уганда школьница ровненский ничья материк завозить авиалайнер африканский идеально кинофильм бегство шариат мадагаскар зарождаться кабина_пилот оборонительный вирус_распространение промысел газа_сектор мобилизовать президентство лихорадка_эпидемия гектар_площадь вспышка_лихорадка исландия_лихтенштейн континент печататься выгонять кения либерия_нигерия пенза ныне пепел бирмингем широко перебой толстый
# topic_d36:[70/4292] рынок проблема влияние изменение сохранять основной оценивать учитывать фактор связанный риск зависеть определять учет повлиять влиять экономика валюта внешний отражать изменять формирование зависимость существовать переход видеть обусловливать способствовать давление валютный сказываться сохранение изменяться привлекать несмотря положение воздействие объясняться показатель особенность важный негативный улучшать снижать демонстрировать необходимо исходить внутренний отражаться меняться ограничение определяться понимать зрение сохраняться соответствовать улучшение хороший ограничивать отсутствие позиция изучать менять переходить испытывать инструмент предполагать текущий состоять заключаться
# topic_d37:[70/324] машиностроение нпо конструкторский созвездие алмазантей опк концерн_уралвагонзавод кб приборостроение алмаз ркк калашников окб энергомаш научнопроизводственный автоматика охотный спму вицепрезидент_исполком интернетресурсы gas укроборонпром впк внешэкономбанк_газпромбанк невский радиосвязь политсовет тракторный мостовик двигатель_рд алмазантей_концерн переправа севмаш рыбина airways studio кооперация разграбить туркменский siemens general_motors похоронный мэр_нефтеюганск порошок нпк калашников_концерн сатурн автомат_гранатомет нии робототехника oil renaultnissan chrysler пао оптикоэлектронный заказ_портфель черноморнефтегаз необитаемый метеорологический вицемэр актив_величина новгородский восточноевропейский ныне замгендиректор сзади вон черт салют куртка
# topic_d38:[70/4811] прикладывать внимательно соблюдать поддаваться тщательно тесно немедленно бомбить немедленный прилагать решительно неизменно воздерживаться забывать выполнять_обязательство практиковаться бойкотировать предпринимать_шаг деэскалация активно важность сдержанность консолидировать дипломат вновь уважать курд трактовка расследовать диалог_налаживание незамедлительно неприемлемый норма_соответствовать попрежний тезис кровопролитие ответственно придерживаться конфронтация осторожность публично эскалация целесообразный спокойно давление_оказывать срочно беспристрастный недружественный решительный конструктивный невиновность спокойствие скоординировать политизировать присоединение_процедура согражданин исключительно активизировать выражать_готовность строго напряженность приветствовать прикладывать_усилие жестко бойкот пан генсек провокационный содействовать серьезно
# topic_d39:[70/4046] решаться задавать задаваться стесняться подымать затрудняться оказание_услуга возбуждение судьба пребывание курировать дальнейший перестановка прорабатывать подниматься прорабатываться целесообразность повестка вопрос_задавать rogozin предстоять спрашивать вставать тематика рассмотрение выноситься гормон_разряд урегулировать ужесточение демократия увязывать вопрос_решаться каков организационный благоустройство компетенция предъявление ставиться разногласие жкх ирония отрабатываться еврокомиссар ключевой спорный тесно журналистка радиовещание проработка заммэра верховенство_право доверие градостроительный отрицательно заданный капелло миграция уклоняться волновать освещать присутствие_расширение королевство_членство определение вопрос_задаваться правовой прояснивать неудобный обсуждаться кино евразия
# topic_d40:[70/3868] роман писатель автор произведение персонаж художник экранизация писательница поэт деятель приключение сказка рассказ трилогия одноименный герой пьеса цикл создатель мотив питер роулинг биография издавать повествовать повесть заканчивать соло люк экранизировать кинорежиссер вейдер волшебник ложиться драматург властелин бестселлер переводить детектив знаменитый ведущий оригинальный дарт агент хоббит кольцо основатель хан умирать псевдоним дизайнер сборник вымышленный критик чубакка описывать инженер композитор озвучивать происхождение вдохновлять принцесса сценарист новелла юный соавтор честь литература модельер популярный
# topic_d41:[70/2484] переговоры встреча четверка нормандский минск формат консультация раунд коллега визит саммит контактный трехсторонний подводить прессконференция женева согласовывать закреплять беседа договоренность_достигать оппозиция вена париж доха брюссель конечный ес госсекретарь стол провал берлин странчлен мид стартовать иранский опек устанавливаться подписывать_протокол констатировать дамаск_согласие белоруссия коммюнике подписание_протокол заканчиваться общаться тройка уславливаться делегация обменяться подписывать_соглашение видеоконференция еврокомиссар семерка усматривать вырабатывать послание середина межсирийский докладывать еврозона конфликт_урегулирование прошедший подписание_соглашение брифинг переписка знакомый донецк астана газовый ожидание
# topic_d42:[70/793] анкара тегеран куба посредник резко шестерка рпк хасан добыча_замораживать переговорщик иран_посредник эррияд проседать суруч осада авиарейс пленный перемирие_соблюдаться багдад кабул серьезно каракас добыча_заморозок лозанна провайдер досье отвод_прекращение канберра хаменей предварительно гарант осведомлять стремительно гавана осаждать исламабад интенсивность_снижаться коррупционер напрямую аравия_катар спокойствие занган оправдываться проповедник нетаньяху sanoma слабость нарушаться heavy бейрут ft значительно films баку продлевать ненужный хэнкс каир атом новоазовск преимущественно подзащитная резолюция_совбез международноправовой революция_страж заметно ненависть_разжигание прикрываться забайкалье демилитаризованный
# topic_d43:[0/0]
# topic_d44:[70/2877] планироваться прибывать посещать отправляться вернуться собираться приостанавливать начинаться завершать совершать участвовать намерен выполнять отправлять отменять приезжать покидать закрывать готовый организовывать запускать включать начало осуществлять приходиться переходить предполагаться вестись останавливать приступать проводиться заключать обеспечивать запланировать вынуждать разрешать возобновлять конец исключать размещать снимать продолжаться восстанавливать рекомендовать предоставлять должно ждать рассчитывать напоминать предусматривать готовиться назначать направляться выбирать предупреждать сокращать открываться зарегистрировать пойти вернуть подавать стартовать возвращение следовать подготовить необходимо возвращаться полет провожать задействовать
# topic_d45:[70/2021] предприятие корпорация завод структура концерн холдинг производитель фирма оао предприниматель комбинат ростеха нефтеперерабатывающий судостроительный госкомпания металлургический включая зао машиностроительный иркут ао нпз роскосмос уралвагонзавод ооо объединять верфь автоваз филиал общество руководство камаз энергия склад работник включаться росатый мечесть изготавливать шахта госпредприятие рособоронэкспорт оака авиастроительный топменеджер монополия производственный студия тракторный перевозчик консорциум усилие уголь заказ конструктор массандра нпк отрасль подразделение гигант механический транснефть производиться обслуживать ssj дочка агрегат gm загружать фгуп
# topic_d46:[70/1327] пункт населенный карабах нагорный пропуск командный процентный преимущественно склад уничтожать узел пропускной дислокация населять временный пограничный провозглашать опорный обстрел армянин_этнический латакия хмеймить материальнотехнический мастерская контрольнопропускной широкино взятие горловка вытеснять вмф назначение взрывчатка жизнедеятельность окрестность полевой обозначать гуково линия_соприкосновение стратегически местность переименовывать проследовать авдеевка марьинка мобильный переименование важный режим_чс обменный разрываться боестолкновение близлежащий прибытие могила нефтеперерабатывающий кпп контрольный разделяться изварино базирование дебальцево курган охватывать переезд переименование_улица волноваха сопредельный бункер досмотр подорваться
# topic_d47:[70/929] бумага ценный облигация долговой портфель выпуск_облигация еврооблигация рублевый евробонд монета репо доходность номинал выкуп депозит переоценка держатель вложение ликвидность гособлигация первичный купюра долларовый банкнот выкупать банкнота расписка эмитент эмиссия туалетный низкокачественный погашение предусматриваться наличный ipo залог инфраструктурный купон упоминаться лист вкладываться скупать бланк банкротство_грань фальшивый solvers реликвия обратный расплачиваться рефинансирование кредитовать конвертировать вторичный корпоративный обанкротиться десятилетний недвижимость дефолт_допускать надежный вэб целесообразность суверенный инвестировать производный выгодно спекуляция доверять привилегированный юань монополия
# topic_d48:[70/3211] провинция поселок село деревня славянск луганск мариуполь север мосул окрестности окраина пальмира недалеко пригород юг краматорск неподалеку северозапад горловка ракка харьков днепропетровск дебальцево окрестность подмосковный северовосток штабквартира счастие блокпост одесса река аден латакия родной иракский багдад берег_река приграничный поселение иордан артемовск близлежащий контролируемый курортный портовый одноименный авдеевка древний югозапад дамаск станица хам кобань артобстрел иерусалим яйладагы зачистка кундуз бежать идлиб широкино углегорск подорваться запорожье новоазовск уезд душанбе горсовет лисичанск металлист
# topic_d49:[70/1727] певица голливудский мадонна леди знаменитость супермодель гага бибер фотосессия исполнительница депп деппа бобби топмодель телеведущая манекенщица кара знаменитый поклонник кончит делевинуть изготовлять херд парадя вурст мосс позировать реалитишоу свифт обложка майль найтли воля_посол танцор хьюстон шоубизнес подруга участница обладательница высокооплачиваемый начинающий обнажать голливуд кайлить художница пожениться сотрудничать женатый нойвирт пик танцовщица шейк разводиться vogue тонуть артистка происхождение оперный навка модельер комедийный телезвезда слава обнаженный playboy телешоу австрийский малоизвестный жениться онил
# topic_d50:[70/1549] состояние алкогольный опьянение_состояние опьянение критический оцениваться нетрезвый самочувствие вождение стабильный удовлетворительный психический мск наркотический бессознательный стабилизироваться кома крайне мониторинг прохождение пребывать ухудшение улучшаться неудовлетворительный плохой стабильно расстройство исправный сильный зависимость освидетельствование езда интоксикация алкогольный_опьянение квантовый неадекватный аварийный боеготовность оставление превышение_скорость покой дерст питание_ресторан потребность бортовый близкие forbes замечание депрессия эмоциональный самописец душевный нормальный отравление безопасный отличный психологический схожий протаскивать пациент спускаться критерий углеводород нахождение вред_причинение руль полотно летчик обследование непригодный
# topic_d51:[70/2132] вводить введение действовать продлять касаться отменять вводиться распространяться применять затрагивать ужесточить продление применяться снятие усиление сохраняться ввод переходить ужесточение подпадать налагать предусматриваться продлевать распространять внедрять потеря обусловливать усиливать обходить сохранять постановление расширение существовать накладывать разъяснять последовать продлиться прорабатывать ослаблять пролонгировать обход осуждение объявление возвращать продлеваться сохранение ухудшаться ввозить внедрение приостановление ужесточать упоминаться ослабление заменять наступать заговаривать сводиться приостановка компенсировать приниматься бояться приветствовать сказываться дружеский опротестовывать оговариваться недополучать разрешать установленный истекать
# topic_d52:[70/2982] неизвестный белый жилой модный частный профсоюз двор улица подъезд аукционный собственный издательский многоквартирный укрываться bulgari сжигать хозяин жилец квартира мода многоэтажный поджигать престарелый дождаться окно итальянский chanel проникать подвал печать ворваться пятиэтажный повреждать переулок ограбить сгорать крыша загородный dior детский выставлять французский ювелирный съемный психоневрологический близлежащий обрушиваться обыск этаж соседний обрушение гостевой воспитанник фасад hermes обкрадывать christian село сожжение запирать гараж номер сосед дизайнер останавливаться выбивать выходец christies поджог распылять
# topic_d53:[70/1147] суд судья прокуратура мосгорсуд арбитраж инстанция коллегия районный трибунал присяжный окружной избирком пресненский гейпарад управляющий процессуальный северокавказский постанавливать горсовет корреспондент санкционировать россельхознадзор мещанский существо постанавливать_суд оправдывать обозреватель загс овд учительница хартия сан комиссариат комиссар управа таганский сказка военкомат дума муфтий вердикт госслужащий доступ_ограничивать усадьба тупик раввин арбитр значение прокурор вал сыктывкар лубянка уводить волеизъявление рапси облизбирком казначейство шах коэффициент амнистировать сталинский командующий судно савеловский дефицит казна переулок подчинение вынести_приговор хантымансийский
# topic_d54:[70/2099] реклама электронный алкоголь сигарета спирт быстрый табак упаковка контора смесь рекламировать питание_ресторан маркировка табачный печатный розничный курение тара допускаться этиловый спиртосодержащий курительный king пластиковый киоск алкогольный_продукция беременность продавец алкогольный егаис прерывание бумажный burger бургер потребление пачка фастфуда продаваться фальсифицировать спиртное кальян наружный полка аукцион распространитель презерватив продукция_спирт громкость оптовый воздействие_дым розница букмекерский чипсы поддельный сувенирный азартный торговать регулирование аптека прочий наценка некачественный контрафактный слоган легальный прилавок интернетмагазин продвигать уличный ларек
# topic_d55:[70/1550] соединять калифорния соединенный флорида техас огайо вирджиния калифорний пенсильвания аризона джорджия массачусетс ньюджерси орегон каролина миссури теннесси мэриленд луизиана иллинойс колорадо мичиган невада оклахома алабама юта коннектикут кентукки индиана арканзас аляска миннесота кливленд висконсин миссисипи айова вермонт ligo канзас дакота небраска мэн легализовать pulse ньюмексико индийский ласвегас калифорнийский санфранциско финикс гавайи линкольн квинсленд выращивать демократ базироваться мехико аравия_бежать остин казнить хьюстон мексиканский бернуть вирджиния_штат техасский капитолий аден югозапад юг атланта
# topic_d56:[70/3878] выпускать одежда бренд коллекция специализироваться обувь аксессуар марка дизайнер производитель модель производить украшение час линейка выпуск мужской женский выпускаться производство спортивный часы продаваться белье модный сотрудничать предмет ювелирный изделие косметика парфюмерия разрабатывать сумка собственный класс мода продажа запускать аксессуар_одежда люкс дизайн техника серия модельер nike показ аромат обувь_одежда кампания продавать кожа посвящать вещь мебель стиль сегмент фирма детский вдохновлять chanel сотрудничество компанияпроизводитель повседневный кроссовок лимитировать итальянский уход интерьер бутик название
# topic_d57:[70/1376] вода территориальный горячий жидкость питьевой река лед ведро выливать ледяной минеральный жидкий холодный спускать наполнять нехватка обливаться водоем кислород пресный бензин озеро очистка соленый стакан нейтральный проваливаться загрязнение канализационный дно кислота спуск дрейфовать замерзать ванна водоснабжение ощущаться краска идентифицировать прибрежный люк аммиак посягательство_целостность грунтовый чистый яма обливать электричество грязь подземный отопление суша утопать вытекать очищать бассейн еда пища капля колодец купание труба сброс резервуар опрокидывать подъем грязный канализация выливаться извлекать
# topic_d58:[70/5967] признаваться история узнавать любить увидеть желание зритель повествовать смотреть новость ходить нравиться собственный молодой любовь многий чувствовать предпочитать поделиться испытывать опыт мечтать сидеть спрашивать переживать герой поклонник посоветовать спасать коллега играть событие позвонить познакомиться общаться посмотреть глаз вещь понравиться вдохновлять личный стараться часто счастливый знакомый рассказываться бояться парень любимый скрывать переставать многие делиться брать описывать детство ощущение желать наблюдать хотеться пользоваться возвращаться увлекаться тема ждать персонаж употреблять уезжать надевать поступок
# topic_d59:[70/534] миссия обсе наблюдатель мониторинговый смм миссия_наблюдатель сцкк наблюдательный фиксироваться фиксировать невыполнимый мандат крест инспектор соблюдение_стандарт спецпредставитель пролив мккк развертывание комиссар_управление посланник вброс поделить посредничество ежедневный постпред миротворец повышение_эффективность еспча кредитор_тройка патруль странучастница фиксация патрулирование придание делегат наблюдатель_обсе хельсинки аккредитация объективность вызывать_нарекание засада спрятать арест_налагать военноморский сторонний фотокорреспондент зил сгорать дейний объективный полевой дочка афганский поджог важность широкино многопрофильный нарышкино белград оценочный вероятно ашхабад участковый игнорировать нацсовет меморандум_подписывать продлеваться либеральный госбанк
# topic_d60:[70/3507] срок приговаривать лишение свобода заключение вид отбывать тюрьма назначать домашний осуждать колония тюремный пожизненный продлять казнь смертный приговор колония_режим содержание строгий освобождать просить осужденный помещать исправительный условно заменять продление условный сутки заключенный лишение_приговаривать ограничение полномочие россиянин обвиняемый истекать исполнение отпускать отбывание максимальный пребывание вынести содержаться обвинительный освобождение фигурант час сокращать смягчать заключение_приговаривать лишение_свобода половина реальный полгода наказание_отбывание истечение_срок отменять обвиняться наказание_отбывать предусматриваться следствие ходатайство заканчиваться помиловать отсрочка постанавливать лишение_отбывание колониипоселение
# topic_d61:[70/92] rutracker хирургический подрывной переписка_разговор ведение_слежка оперативнорозыскной оперативноразыскной внешнеэкономический батальон_днепр разговор_слежка лицензия_отзывать вводить_заблуждение оперативноследственный аналоговый внешнеторговый будда госконцерт лесной_хозяйство меджлис_татарин ipad_iphone club учредительный габарит врачебный татнефть вступать_сговор основание_послужить airline застреливать_подросток оружие_стрелковый обрыв эксмо подсобный периодичность искусство_произведение гмия вкладка бардо деление бот декларирование округ_сибирский politico ведение_предназначать бухгалтерский lab молдова короткометражка приближенный госвласть запястье tomb стивенс застройщик курганский букмекер война_отечественный гипотеза_проверять архиепископ выяснение_обстоятельство профессионально бесполезный неожиданность гувд самоубийца andrew декабрьский планшет_смартфон воспрепятствование маг
# topic_d62:[70/2362] режим особый установление огонь_прекращение закрепление_статус безвизовый вооружение_отвод тяжелый визовый прописывать чрезвычайный отдельный штатный чс реальный проведение_установление обычный экономия переводить свержение колония предоплата диалог контртеррористический обмен_пленный прежний тоталитарный закрытый автоматический строгий децентрализация усиленный тестовый облегчение тишина конституционный нацистский либерализация_режим невозможно коммунистический закрепление_режим закрепление_установление переходить чп льготный ускорение отвод пленный правовой выделение ликвидация соблюдаться закон_осуждение упрощение смягчение либерализация конституция_поправка усиление замораживание править повышенный пропаганда конституция многопользовательский инициатор консультация перемирие координация ручной соблюдать
# topic_d63:[70/2278] газ топливо кубометр транзит природный уголь газовый электроэнергия хранилище предоплата транспортировка закупать выброс закачивать хватить импортировать применять сокращать голубой нафтогаз пхг сжиженный подземный ресурс потребление покупать платить нефтепродукт скидка потребитель маршрут электричество энергоноситель договариваться слезоточивый переработка реверс углекислый конденсат подача накапливать экспортировать сырье поставляться заявка зависимость реверсный парниковый закачка отбор гарантировать зимний добывать высказывать_мнение потреблять потребность увеличивать диверсификация перекрывать зима транспортировать углеводород накоплять спг заполнять тариф отбирать бензин бытовой треть
# topic_d64:[70/2364] силовик пограничник летчица авиагруппа_состав бомбардировщик_сбивать националист летчица_надежда itunes_чарт журналист_телекомпания примирение таможенник сср пособничество_убийство десантник премьерлига_тур бомбардировщик_су монополист въезд_грузовик субъект_федерация itunes консул тяжеловес карта_обслуживать помиловать байкер заполнять_хранилище мотоциклист спецназовец кпп триколор интернетресурсы легкоатлет_отстранять правозащитница фотомодель гимн_исполнение государственность еврооблигация погранслужба правоохранитель таможня соучастие_убийство лира блокпост дочка пранкер батальон_боец диспетчер евробонд галатасарай реалия политолог сапер наркополицейский сухогруз кабмин вгтрк радикал приватбанк репортер национализм контролироваться дилер авиадиспетчер затрагивать_сектор этапировать неизменно эстрада вымпелком минкульт авиаударов
# ...
# topic_d388:[70/844] мощность газопровод нитка трубопровод прокладка пролагать дно_море протяженность магистральный пропускной мегаватт газопровод_строительство кубометр_способность труба производственный дно нитка_строительство лошадиный нефтепровод суммарный километр_протяженность годовой подразумевать_расширение ветка прокладка_способность проектный балтийский загружать stream энергомост кабель законсервировать укладка спг хаб генерировать диверсификация магистраль south перенаправлять удваивать автозавод прорыв газотранспортный генерация загрузка неконтролируемый ввод изыскание сахалин алтай болгарский высокоэнергетический мощность_нитка голубой еврокомиссия совокупный energy контракт_расторгать расторжение проектировать цепочка способность контрактный экспортный transport подключение свертывать нпз ямал
# topic_d389:[70/2693] заболевание болезнь вирус страдать лечение рак лихорадка больной умирать вспышка пациент препарат расстройство грипп инфекция опасный сердечный риск диабет распространение психический симптом эпидемия приступ недостаточность заражаться диагностировать ожирение синдром сердце заражать заражение смертельный профилактика чума онкологический заболевать острый зик сердечнососудистый инфекционный зарегистрировать хронический вакцина депрессия боль инфаркт терапия вич диагностика лечить вирусный почка форма инсульт туберкулез лекарство характеризоваться печень метод осложнение альцгеймер исход склероз коронавирус шизофрения алкоголизм наблюдаться признак заболевание_страдать
# topic_d390:[70/2554] оружие пистолет боеприпасы автомат снаряд винтовка пулемет калибр гранатомет огнестрельный патрон миномет единица миллиметр граната применять стрелковый артиллерийский ружье стрельба выстрел мина уничтожать вооружать производить склад миллиметровый автоматический пушка орудие обстреливать взрывчатка калашников травматический град стрелять охотничий химический пуля минометный самодельный нож снайперский арсенал боеприпас крупнокалиберный реактивный прицел выстреливать гранат ручной противотанковый взрывной залповый калибр_миллиметр гаубица артиллерия предмет обстрел мало бит поражение табельный похожий пневматический разрываться револьвер попадание предположительно высокоточный
# topic_d391:[70/1345] ущерб налагать компенсация убыток причинять вред возмещение моральный взыскивать понести материальный возмещать репутация наносить_ущерб вред_компенсация вменять причинять_ущерб компенсировать неустойка нанесение увлечение возмещение_вред комплектовать ответчик урон причинение возмещение_ущерб деловой возмещать_ущерб побои страдание взыскание истец издержка потерпевший рекордный существенный оккупация выплачивать_компенсация издержки понести_убыток имущественный опровержение алименты присуждать достоинство_честь вкладчик понести_потеря отсуживать огромный квалифицироваться подсчитывать окружающий судиться порочить вред_причинять чрезмерный обосновывать увечье отступное репутационный страховщик испортить терпеть проливать недобросовестный привилегированный бу махинация извинение
# topic_d392:[70/1529] команда клуб лига премьерлига дивизион первенство парк лига_плейофф премьерлига_тур кхл хоккеист снайпер нхл автомобилист хит кливленд фнл объединение забросить трофей отъезд ска мальорка площадка комментатор розыгрыш арабский комиссар клюшка бонус подраться сборный майка нба прописка эгида шайба барс зал_слава штабквартира денвер функционер подчиняться астана опыт лед легионер хронометрист сибирь уведомлять премьерлига_таблица правление_председатель блюз ак новичок симулятор бруклин нежелание спонсор руководство краснобелый талисман профсоюз шоу заводить магнитогорский утвердить кавальерс пожертвовать вклад_вносить
# topic_d393:[70/4421] мид внешнеполитический чечня газпром минфин еврокомиссия надзорный кабмин цб минэкономразвития юнкер роснефть минэнерго пентагон роскомнадзор центробанк ростуризм улюкаев сбу жанклод делегация пушок оборонный роскосмос цик ржд чеченский россельхознадзор минпромторг минсельхоз плотницкий дипломатия роспотребнадзор фракция сбербанк юкос минкомсвязь представительство сечина одесский минтранс фас думский минздрав генерал регулятор нафтогаз лаборатория профсоюз ек областной мвф евросовет врио нацбанк профильный центризбирком антимонопольный минюст данкверт apple конгресс пучок информационный минкульт наносить госдеп конституционный европарламент контрольный
# topic_d394:[70/2358] мвд эвакуировать мчс выезжать спасатель ликвидировать оцеплять пожарный пресекать происшествие прибыль осматривать дежурить вызов срабатывать медик сопровождение обследовать проинформировать обезвреживать эвакуация перекрывать наряд сопровождать обстреливать прибытие осмотр задействовать закладывать позвонить расчет звонок сапер выдвигаться привлекаться разыскивать охранять кинолог спецназ приезд перебрасывать патрулировать стягивать предотвращать подключаться констатировать уничтожать спецподразделение подъезжать допрашивать потушить патруль психолог оперативник омон авиационный извлекать увезти скрываться чрезвычайный подтвердить информировать дорожнотранспортный опрашивать единица волонтер нейтрализовать звонить карета_помощь погрануправление
# topic_d395:[70/3025] оснащать камера оборудование процессор специальный оборудовать датчик частота модуль прибор панель бортовой видеонаблюдение батарея снабжать радар разрешение видеокамера аккумулятор гигабайт наблюдение сигнал обладать емкость кнопка дисплей сенсор аппаратура встраивать встроенный компьютер экран snapdragon оперативный конструкция установка построить гигабайт_память мегапиксельный оснащаться зарядка выясняться срабатывать оптический механизм радиоэлектронный крепление лазерный управлять фронтальный башня коробка мощный сигнализация кабина решетка гигагерц генератор чип электрический задний элемент функция микрофон устанавливаться бортовый пушка комната wifi телефон
# topic_d396:[70/3247] модель смартфон iphone экран apple планшет часы samsung анонсировать ipad доступный watch модификация гаджет дисплей умный поколение отличаться galaxy ноутбук линейка компьютер корпус дюймовый дюйм pro продажа гигабайт новинка edition диагональ стекло macbook владелец touch процессор lg выпускать флагманский телевизор mini продаваться телефон версия note разрешение выпуск дизайн стоить презентация покрытие час предыдущий миллиметр android оснащать снабжать выпускаться сапфировый edge реализовать nexus lumia приставка начинаться сенсорный анонс производитель ipod память
# topic_d397:[70/674] экспертный снбо пасе цк координационный спч нацбезопасность попечительский кпсс полноправный оон_пан обком консультативный генсовет компартия еврогруппа политсовет радиовещание суг унаунсо ер план_расселение муфтий информационноаналитический радиовещание_телевидение пан научнотехнический физкультура бабушкин тускнуть русала сф ассамблея_сессия директива природопользование страсбург pirelli редакционный продолжительность_увеличение инфантино межнациональный тува удовольствие беляк переводчик еврозона cnpc qiwi персидский фк тюльпан доплата доктрина вступаться заведующий_отдел пургин тпк кпу революционный академик магатэ деревенский эмигрировать газпроммедиа вто заочный выборгский жизненный рсмд вб
# topic_d398:[70/2386] медицинский гуманитарный скорый оказание психологический пострадавший лечебный исправительный материальный нуждаться неотложный fjsdocument экстренный прохождение медик дамаск психолог фельдшер основание_распоряжение консульский срочный нуждающийся дошкольный приезд ракетыноситель пенитенциарный допуск раненый макрофинансовый медикамент военнотехнический ускорение delta понадобиться прибегать правовой лазер казенный дрон высокотехнологичный отравлять волонтер водомет больной разгонять микроскоп санаторнокурортный компьютерный квалифицированный медпомощь психиатрический бросаться краудфандинг вакцина учредитель atlas посторонний пожертвование адресный позвать кран халатность госпитализация sms томография продовольственный снаряжение беспилотник сообщник благодарность
# topic_d399:[70/648] аравия обязываться обогащать уран преобразовывать обогащение фордо технологический перестраивать аравия_катар консорциум вывозиться аравия_король аятолла аден аравия_бежать несогласие порог плутоний оплот реактор остальное нептун вооружаться вменяться показательный коллаборация царить акционерный онлайнсервис проповедник разгромить профильный стс правомерность ремонтировать совмещать либерал приднестровье ливан нефтебаза линия_отводить безумие процветать вдохновляться нестабильность пропорционально рфпи интересно зрс полнота своеобразный воздерживаться_поездка мема конфликт_эскалация круговой моторный подсказывать перевозиться эльбрус гипотетический вывоз мавзолей взяться назваться наслаждение аккредитация погром стабильный ось
# topic_b0:[70/17091] становиться имя занимать входить место представлять выходить первый появляться выступать попадать группа создавать получать новый основывать российский показывать объявлять включать проходить оказываться рассказывать возглавлять работа проводить россия оставаться выпускать компания мировой версия начинать считаться крупный выбирать состояться планировать проект часть состав продолжать история большой участник создание опубликовывать канал заниматься поставлять выход отказываться сша принадлежать хороший предлагать итог программа лидер качество ряд вести страна название продавать покидать организация уходить приносить собирать
# topic_b1:[70/17091] не имя россия страна место результат российский город первый украина сша москва новый житель мужчина летний хотеть ребенок добавлять рассказывать удаваться конец случай тысяча гражданин решать начинать группа территория помощь лицо местный ход получать жизнь процент работа часть представитель участник выходить киев итог второй собираться россиянин происходить показывать сторона регион уточнять государство помогать отказываться власть большой возможность самолет ученый военный сотрудник область позволять документ давать семья компания приходиться оказываться появляться
# topic_b2:[70/17091] процент компания система проект позволять предлагать средство новый получать работа планировать создавать создание становиться возможность россия планироваться заниматься использовать российский часть решение намерен ряд начинать обеспечивать страна устанавливать производство предусматривать включать представлять входить цель организация стоимость пояснять поток объявлять добавлять рынок направлять центр продажа предполагаться вид счет обеспечение предполагать крупный приводить сеть поддерживать связывать готовый запрещать увеличивать предложение вопрос условие решать необходимо подчеркивать оставаться передача проводить уточнять использование использоваться регион
# topic_b3:[70/17091] имя президент глава рассказывать становиться бывший выступать летний написать получать предлагать компания председатель занимать задерживать выражать представитель встреча россия пояснять добавлять оказываться обвинять подчеркивать журналист отношение украина прокомментировать призывать барак подтверждать появляться сын область входить мнение проводить отказываться подавать попадать назначать российский объявлять руководитель участвовать давать приводить вопрос москва отправлять выходить решать группа признавать отвечать объяснять уточнять опубликовывать дом сша посещать город работа приезжать кандидат проект основатель обращаться письмо роман
# topic_b4:[70/17091] сила российский военный действие имя помощь часть состав цель начинать создавать создание территория техника система использовать украина сторона самолет входить группа получать подготовка проводить сша применение направлять средство выполнять обеспечение позволять оказывать новый объект работа участвовать обеспечивать использоваться объявлять планироваться прекращение война подчеркивать использование продолжать район сбивать проходить действовать россия осуществлять задача воздушный центр устанавливать ряд станция удаваться включая представлять возможность начинаться уточнять становиться включать безопасность готовность планировать совершать вывод
# topic_b5:[70/17091] решение вопрос подчеркивать становиться отношение ситуация выражать приводить добавлять призывать возможность случай страна сторона действие украина вызывать власть давать условие пояснять продолжать не связывать решать работа отказываться россия цель безопасность объяснять хотеть поддерживать ряд позволять направлять выступать готовый оставаться уровень предлагать помогать указывать мнение возможный необходимость проблема имя позиция необходимо признавать российский организация правительство регион происходить напоминать проект политический создание государство высказывать проведение намерен должно конфликт политика новый москва отвечать
# topic_b6:[70/17091] россия украина глава страна президент представитель объявлять сша имя выступать предлагать признавать обращаться поддерживать российский становиться призывать направлять организация входить отказываться проводить решение начинать запрещать получать рф отношение подчеркивать власть проходить выражать ряд обвинять опубликовывать вопрос подтверждать состояться добавлять занимать создавать рассказывать намерен представлять территория готовый напоминать давать москва итог регион планировать решать попадать государство киев состав сторона одобрять прокомментировать вносить поддержка пытаться член лидер участвовать руководство действовать возглавлять оставаться
# topic_b7:[70/17091] происходить проходить проводить область результат город ход начинаться состояться имя становиться начинать объявлять москва проведение территория центр задерживать проводиться итог участник рассказывать начало устанавливать приводить получать местный участвовать обнаруживать выступать оказываться продолжаться вызывать планировать место киев зафиксировать попадать появляться район организовывать часть ряд отказываться удаваться власть выходить рамка устраивать продолжать приходить попытка регион акция посвящать столица случай решение вести показывать оставаться признавать направлять назначать решать открывать возбуждать подтверждать смена работа
# topic_b8:[70/17091] организация сотрудник управление служба задерживать имя представитель безопасность центр полиция область отношение глава компания ведомство группа рассказывать россия власть часть признавать обращаться москва направлять работа сообщение местный руководитель прокуратура ряд деятельность заниматься уточнять министерство проводить отделение действие город устанавливать украина округ пояснять решение военный подтверждать вопрос обнаруживать департамент мвд регион контроль расследование создавать руководство рф подразделение гражданин государственный работник происходить структура правительство новость проверка аэропорт движение здание отдел район становиться
# topic_b9:[70/17091] получать становиться обнаруживать рассказывать оказываться устанавливать находить имя появляться позволять показывать удаваться использовать предлагать приводить представлять давать признавать начинать происходить добавлять проводить оставаться решать создавать попадать вызывать помогать хотеть задерживать уточнять подчеркивать обращаться пояснять открывать приходить отказываться запрещать выходить связывать пытаться указывать планировать проходить объяснять помощь подтверждать часть выяснять использоваться направлять заниматься приходиться жизнь предполагать случай жить оставлять считаться вести призывать поддерживать мужчина собирать написать предоставлять оказывать работа количество возможность
